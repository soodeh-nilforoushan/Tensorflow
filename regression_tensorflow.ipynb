# %% [markdown]
# <a href="https://colab.research.google.com/github/soodeh-nilforoushan/Tensorflow/blob/main/regression_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import the Boston pricing dataset from TensorFlow tf.keras.datasets and model it.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
(X_train, y_train), (X_test, y_test)=tf.keras.datasets.boston_housing.load_data(
    path='boston_housing.npz', test_split=0.2, seed=113
)

# %%
X_test.shape,X_train.shape, y_test.shape, y_train.shape
# Out:
# ((102, 13), (404, 13), (102,), (404,))

# %%
# Set random seed
tf.random.set_seed(113)

# Create a new model (same as model_2)
model1 = tf.keras.Sequential([
  tf.keras.layers.Dense(200),
  tf.keras.layers.Dense(200),
  tf.keras.layers.Dense(150),
  tf.keras.layers.Dense(100),
  tf.keras.layers.Dense(1)
])

# Compile the model
model1.compile(loss=tf.keras.losses.mae,
                        optimizer=tf.keras.optimizers.Adam(),
                        metrics=['mae'])

# Fit the model
history=model1.fit(X_train, y_train, epochs=300)
# Out:
# Epoch 1/300
# 13/13 [==============================] - 1s 5ms/step - loss: 125.9035 - mae: 125.9035
# Epoch 2/300
# 13/13 [==============================] - 0s 5ms/step - loss: 39.1406 - mae: 39.1406
# Epoch 3/300
# 13/13 [==============================] - 0s 4ms/step - loss: 20.4025 - mae: 20.4025
# Epoch 4/300
# 13/13 [==============================] - 0s 5ms/step - loss: 9.3140 - mae: 9.3140
# Epoch 5/300
# 13/13 [==============================] - 0s 5ms/step - loss: 7.0536 - mae: 7.0536
# Epoch 6/300
# 13/13 [==============================] - 0s 5ms/step - loss: 6.4948 - mae: 6.4948
# Epoch 7/300
# 13/13 [==============================] - 0s 4ms/step - loss: 7.1692 - mae: 7.1692
# Epoch 8/300
# 13/13 [==============================] - 0s 4ms/step - loss: 6.9250 - mae: 6.9250
# Epoch 9/300
# 13/13 [==============================] - 0s 6ms/step - loss: 6.2036 - mae: 6.2036
# Epoch 10/300
# 13/13 [==============================] - 0s 4ms/step - loss: 6.4684 - mae: 6.4684
# ...

# %%
model1.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 4.2117 - mae: 4.2117
# [4.211737632751465, 4.211737632751465]

# %%
# Make and plot predictions for model_1
y_preds_1 = model1.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
# Plotting the loss Vs Epoch
pd.DataFrame(history.history).plot()
plt.ylabel('loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')
